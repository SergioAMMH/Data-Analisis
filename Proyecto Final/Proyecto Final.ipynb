# %% [markdown]
# # Financial Python

# %%
import pandas_datareader.data as web

# %%
import datetime

# %%
start = datetime.datetime(2005, 1, 1)
end = datetime.datetime.now()

# %%
#API Key 9MX4A6S34LT5V4JU
k= '9MX4A6S34LT5V4JU'

# %%
symbol = 'AAPL'
api_key = k  # Reemplaza 'tu_clave_de_api' con tu propia clave de API
data = web.DataReader(symbol, 'av-daily', start, end, api_key=api_key)

print(data.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas_datareader\av\__init__.py:72, in AlphaVantage._read_lines(self, out)
#      71 try:
# ---> 72     df = pd.DataFrame.from_dict(out[self.data_key], orient="index")
#      73 except KeyError:
#
# KeyError: 'Time Series (Daily)'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDataError                           Traceback (most recent call last)
# Cell In[9], line 3
#       1 symbol = 'AAPL'
#       2 api_key = k  # Reemplaza 'tu_clave_de_api' con tu propia clave de API
# ----> 3 data = web.DataReader(symbol, 'av-daily', start, end, api_key=api_key)
#       5 print(data.head())
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\data.py:568, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     556     return AVTimeSeriesReader(
#     557         symbols=name,
#     558         function="FX_DAILY",
#    (...)
#     564         api_key=api_key,
#     565     ).read()
#     567 elif data_source == "av-daily":
# --> 568     return AVTimeSeriesReader(
#     569         symbols=name,
#     570         function="TIME_SERIES_DAILY",
#     571         start=start,
#     572         end=end,
#     573         retry_count=retry_count,
#     574         pause=pause,
#     575         session=session,
#     576         api_key=api_key,
#     577     ).read()
#     579 elif data_source == "av-daily-adjusted":
#     580     return AVTimeSeriesReader(
#     581         symbols=name,
#     582         function="TIME_SERIES_DAILY_ADJUSTED",
#    (...)
#     588         api_key=api_key,
#     589     ).read()
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\base.py:101, in _BaseReader.read(self)
#      99 """Read data from connector"""
#     100 try:
# --> 101     return self._read_one_data(self.url, self.params)
#     102 finally:
#     103     self.close()
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\base.py:113, in _BaseReader._read_one_data(self, url, params)
#     111 else:
#     112     raise NotImplementedError(self._format)
# --> 113 return self._read_lines(out)
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\av\time_series.py:114, in AVTimeSeriesReader._read_lines(self, out)
#     113 def _read_lines(self, out):
# --> 114     data = super(AVTimeSeriesReader, self)._read_lines(out)
#     115     # reverse since alphavantage returns descending by date
#     116     data = data[::-1]
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\av\__init__.py:81, in AlphaVantage._read_lines(self, out)
#      75         raise ValueError(
#      76             "The requested symbol {} could not be "
#      77             "retrieved. Check valid ticker"
#      78             ".".format(self.symbols)
#      79         )
#      80     else:
# ---> 81         raise RemoteDataError(
#      82             " Their was an issue from the data vendor "
#      83             "side, here is their response: {}".format(out)
#      84         )
#      85 df = df[sorted(df.columns)]
#      86 df.columns = [id[3:] for id in df.columns]
#
# RemoteDataError:  Their was an issue from the data vendor side, here is their response: {'Information': 'Thank you for using Alpha Vantage! This is a premium endpoint. You may subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly unlock all premium endpoints'}

# %%
import yfinance as yf

# %%
data = yf.download(symbol, start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(data.head())
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2005-01-03  1.156786  1.162679  1.117857  1.130179   0.960587   691992000
# 2005-01-04  1.139107  1.169107  1.124464  1.141786   0.970453  1096810400
# 2005-01-05  1.151071  1.165179  1.143750  1.151786   0.978952   680433600
# 2005-01-06  1.154821  1.159107  1.130893  1.152679   0.979711   705555200
# 2005-01-07  1.160714  1.243393  1.156250  1.236607   1.051045  2227450400

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(data)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2005-01-03    1.156786    1.162679    1.117857    1.130179    0.960587
# 2005-01-04    1.139107    1.169107    1.124464    1.141786    0.970453
# 2005-01-05    1.151071    1.165179    1.143750    1.151786    0.978952
# 2005-01-06    1.154821    1.159107    1.130893    1.152679    0.979711
# 2005-01-07    1.160714    1.243393    1.156250    1.236607    1.051045
# ...                ...         ...         ...         ...         ...
# 2023-06-01  177.699997  180.119995  176.929993  180.089996  180.089996
# 2023-06-02  181.029999  181.779999  179.259995  180.949997  180.949997
# 2023-06-05  182.630005  184.949997  178.039993  179.580002  179.580002
# 2023-06-06  179.970001  180.119995  177.429993  179.210007  179.210007
# 2023-06-07  178.440002  181.210007  177.320007  177.820007  177.820007
#
#                 Volume
# Date
# 2005-01-03   691992000
# 2005-01-04  1096810400
# 2005-01-05   680433600
# 2005-01-06   705555200
# 2005-01-07  2227450400
# ...                ...
# 2023-06-01    68901800
# 2023-06-02    61945900
# 2023-06-05   121946500
# 2023-06-06    64848400
# 2023-06-07    61889100
#
# [4639 rows x 6 columns]

# %%
df['Open'].plot(label='Aple',figsize=(12,8), title='Opening Prices')
# Out:
# <Axes: title={'center': 'Opening Prices'}, xlabel='Date'>

# %% [markdown]
# # Replicamos para otros 3 ejemplos.

# %%
# Obtener datos de Disney (símbolo: DIS)
disney = yf.download('DIS')

Disney = pd.DataFrame(disney)

# Obtener datos de Marvel (símbolo: MRVL)
marvel = yf.download('MRVL')

Marvel = pd.DataFrame(marvel)

# Obtener datos de Sony (símbolo: SNE)
sony = yf.download('SNE')


Sony = pd.DataFrame(sony)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ERROR
# 1 Failed download:
# ERROR ['SNE']: Exception('SNE: No timezone found, symbol may be delisted')

# %%
# Obtener datos de Sony (símbolo: SNE)
sony2 = yf.download('SONY')


Sony2 = pd.DataFrame(sony2)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Sony2
# Out:
#                  Open        High        Low       Close   Adj Close  Volume
# Date
# 1973-02-21   0.000000    7.927273   7.672727    7.763636    5.828178  378125
# 1973-02-22   0.000000    7.763636   7.581818    7.581818    5.691688  225500
# 1973-02-23   0.000000    7.563636   7.400000    7.436364    5.582494  173250
# 1973-02-26   0.000000    7.454545   7.181818    7.327273    5.500599  422125
# 1973-02-27   0.000000    7.327273   7.163636    7.163636    5.377756  250937
# ...               ...         ...        ...         ...         ...     ...
# 2023-06-01  96.190002   97.050003  96.160004   96.660004   96.660004  968700
# 2023-06-02  98.050003   98.860001  97.930000   98.010002   98.010002  676400
# 2023-06-05  98.989998   99.099998  98.389999   98.500000   98.500000  672400
# 2023-06-06  99.000000  100.239998  98.790001  100.050003  100.050003  754100
# 2023-06-07  98.300003   98.800003  97.629997   97.680000   97.680000  735600
#
# [12685 rows x 6 columns]

# %%
df['Open'].plot(label='Aple',figsize=(16,8), title='Opening Prices')
Sony2['Open'].plot(label='Sonny',figsize=(16,8), title='Opening Prices')
Sony['Open'].plot(label='Sonny',figsize=(16,8), title='Opening Prices')
Marvel['Open'].plot(label='Marvel',figsize=(16,8), title='Opening Prices')
Disney['Open'].plot(label='Disney',figsize=(16,8), title='Opening Prices')
plt.legend();

# %%
from pandas.plotting import scatter_matrix

# %%
var_comp = pd.concat([df['Open'],Marvel['Open'],Sony['Open']],axis=1)

# %%
var_comp.columns = ['Apple Open', 'Marvel Open', 'Sony open']

# %%
var_comp.describe()
# Out:
#         Apple Open  Marvel Open  Sony open
# count  4639.000000  5770.000000        0.0
# mean     40.868128    19.538023        NaN
# std      48.447387    14.297734        NaN
# min       1.139107     2.140625        NaN
# 25%       6.658215    10.910625        NaN
# 50%      22.535713    15.555000        NaN
# 75%      46.941250    21.447501        NaN
# max     182.630005    91.330002        NaN

# %% [markdown]
# ## No podemos realzar un Scatter  Plot debido a la falta de información que poseemos
# Este error nace del cambio en el nombre del grupo Sony de SNE a SONY parael mercado de la bolsa, por ello, hay varios valores vacios, lo cual impide que se desarrolle de forma optima alguans comparaciones.

# %%
var_comp['Sony open'] = var_comp['Sony open'].fillna(Sony2['Open'])

# %%
var_comp.describe()
# Out:
#         Apple Open  Marvel Open    Sony open
# count  4639.000000  5770.000000  5770.000000
# mean     40.868128    19.538023    45.120972
# std      48.447387    14.297734    25.014346
# min       1.139107     2.140625     9.600000
# 25%       6.658215    10.910625    27.862501
# 50%      22.535713    15.555000    38.424999
# 75%      46.941250    21.447501    53.700001
# max     182.630005    91.330002   133.559998

# %%
pd.plotting.scatter_matrix(var_comp, figsize=(8, 8), alpha=0.2)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import SVC, SVR

# %% [markdown]
# # Regresión para Marvel

# %%
n= len(Marvel)

x = int(n*0.9)

X_E = Marvel[:x]
X_T = Marvel[x:]

y_T = X_T["Close"]
y_E = X_E["Close"]

X_E = X_E.drop(["Close","Adj Close"], axis=1)
X_T = X_T.drop(["Close","Adj Close"], axis=1)

# %%
Marvelsvr = SVR()
Marvelsvr.fit(X_E, y_E)
y_pred = Marvelsvr.predict(X_T)

# %%
print('Score: ', Marvelsvr.score(X_T, y_t))
# Out:
# Score:  -9.181104312249477

# %%
MarvelForest = RandomForestRegressor()
MarvelForest.fit(X_E, y_E)
y_pred = MarvelForest.predict(X_T)
# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(y_T, y_pred)
print("Error cuadrático medio (MSE):", mse)

# Calcular el coeficiente de determinación (R^2)
r2 = r2_score(y_T, y_pred)
print("Coeficiente de determinación (R^2):", r2)
# Out:
# Error cuadrático medio (MSE): 110.08482503709384
# Coeficiente de determinación (R^2): 0.3439194074036388

# %%
import numpy as np
y_combined = np.concatenate((y_T, y_pred))
y_combined
df_P = pd.DataFrame(y_combined)

# %%
X_T.columns
# Out:
# Index(['Open', 'High', 'Low', 'Volume'], dtype='object')

# %%
X_T
# Out:
#                  Open       High        Low    Volume
# Date
# 2021-02-23  48.200001  49.400002  46.680000  13210700
# 2021-02-24  48.590000  49.279999  47.450001  12785300
# 2021-02-25  48.900002  49.419998  46.139999  11476400
# 2021-02-26  47.349998  48.590000  46.619999  11501100
# 2021-03-01  49.090000  49.560001  48.189999   9344400
# ...               ...        ...        ...       ...
# 2023-06-01  59.389999  62.099998  58.610001  24980300
# 2023-06-02  62.220001  62.480000  59.130001  18012300
# 2023-06-05  59.580002  59.599998  57.259998  15900500
# 2023-06-06  58.099998  60.310001  58.040001  16472000
# 2023-06-07  62.259998  63.639999  59.110001  23810900
#
# [577 rows x 4 columns]

# %%
Marvel['Close'].plot(label='Marvel',figsize=(16,8), title='Opening Prices')
plt.plot(X_T.index,y_pred)
